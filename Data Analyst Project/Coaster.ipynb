# %% [markdown]
# # **Coaster dataset**

# %% [markdown]
# # This Coaster dataset has information about the over 1000 rollercoasters

# %%
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt 
import seaborn as sns
plt.style.use('ggplot')
# pd.set_option('max_columns',200)

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/coaster_db.csv")

# %% [markdown]
# # **1. Data understanding**
#
# * Dataframe shape
# * head and tail
# * dtype
# * describe

# %% [markdown]
# # **Data Dictionary**

# %% [markdown]
# * Coaster_name  ---> Name of Coaster
# * Location  --->  Location of the Coaster
# * Status ---> Status of Coaster
# (Removed/Close/NaN/Under construction/Operating)
# * Opening date ---> Opening date of Coaster
# * Manufacturer ---> Manufacturer name of Coaster
# * year_introduced ---> The category is for roller coasters
#   which were introduced in the year
# * latitude ---> The latitude Values of Roller Coasters
# * longitude ---> The Longitube values of Roller Coaster
# * Type_Main  --->Type of Coaster like -Wood / Steel/ Other
# * opening_date_clean ---> Coaster opening clean date
# * speed_mph  ---> Speed of Coaster in Minute Per Hours
# * height_ft ---> Speed of Coaster In feet
# * Inversions_clean ---> Coaster inversions Clean

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.tail()
# Out:
#                         coaster_name                Length  \
# 1082         American Dreier Looping    3,444 ft (1,050 m)
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1082         53 mph (85 km/h)                       Other                 NaN
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1082            NaN                                 Steel
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# # 2. Data Preperation
#  * Droppin irreleavant columns and rows
#  * identifying duplicated columns
#  * Renaming Columns
#  * feature Creation

# %%
df1=df[['coaster_name', 
    #'Length', 'Speed', 
    'Location', 'Status', 'Opening date',
       #'Type', 
    'Manufacturer',
    #'Height restriction', 'Model', 'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
      # 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
      # 'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date',
     'Opened', 
    #'Replaced by', 'Website',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       
    'year_introduced',
    'latitude', 'longitude', 'Type_Main',
      'opening_date_clean', 
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df1.shape
# Out:
# (1087, 15)

# %%
df1.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Opening date           object
# Manufacturer           object
# Opened                 object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
df['opening_date_clean']= pd.to_datetime(df['opening_date_clean'])

# %%
df1['year_introduced']=pd.to_numeric(df1['year_introduced'])

# %%
# rename columns

# %%
df1.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Opening date', 'Manufacturer',
#        'Opened', 'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed_mph', 'height_ft', 'Inversions_clean',
#        'Gforce_clean'],
#       dtype='object')

# %%
df1.rename(columns={'coaster_name':'Coaster_name','year_introduced':'Year_introduced','opening_date_clean':'Opening_date', 'speed_mph':'Speed_mph','height_ft':'Height_ft','Inversions_clean':'Inversions','Gforce_clean':'Gforce'
       'Gforce_clean'},inplace=True)

# %%
df1.shape
# Out:
# (1087, 15)

# %%
df1.isnull().sum()
# Out:
# Coaster_name             0
# Location                 0
# Status                 213
# Opening date           250
# Manufacturer            59
# Opened                1060
# Year_introduced          0
# latitude               275
# longitude              275
# Type_Main                0
# Opening_date           250
# Speed_mph              150
# Height_ft              916
# Inversions               0
# GforceGforce_clean     725
# dtype: int64

# %%
df1.loc[df1.duplicated(subset=['Coaster_name'])]
# Out:
#                             Coaster_name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Opening date  \
# ...

# %%
df1.query('Coaster_name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_name            Location   Status Opening date  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed         1926
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed         1926
#
#           Manufacturer Opened  Year_introduced  latitude  longitude Type_Main  \
# 39  Traver Engineering    NaN             1926   42.8617   -79.0598      Wood
# 43  Traver Engineering    NaN             1927   42.8617   -79.0598      Wood
#
#    Opening_date  Speed_mph  Height_ft  Inversions  GforceGforce_clean
# 39   1926-01-01       60.0        NaN           0                 4.0
# 43   1926-01-01       60.0        NaN           0                 4.0

# %%
df2=df1.loc[~df1.duplicated(subset=['Coaster_name','Location','Opening_date'])].reset_index(drop=True).copy()

# %% [markdown]
# # 3. Feature Understanding
# (Univariable analysis)
#
# * Plotting Feature Distributions
#   * Histogram
#   * KDE
#   * Boxplot

# %%
ax=df2['Year_introduced'].value_counts()\
.head(10)\
.plot(kind='bar',title="top Years Coasters Intruduced")
ax.set_xlabel("Year_Introduced")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax=df2["Speed_mph"].plot(kind='hist',bins=20,title="Coaster Speed(mph)")
ax.set_xlabel("Speed mph")
# Out:
# Text(0.5, 0, 'Speed mph')

# %%
ax=df2["Speed_mph"].plot(kind='kde',title="Coaster Speed(mph)")
ax.set_xlabel("Speed mph")
# Out:
# Text(0.5, 0, 'Speed mph')

# %% [markdown]
# # 4. Feature Relationships
#   * Scatterplot
#   * Heatmap Correlation
#   * Pairplot
#   * Groupby comparisons

# %%
ax=df2.plot(kind='scatter',x='Speed_mph',y='Height_ft',title="Coaster Speed vs height")

# %%
sns.scatterplot(x='Speed_mph',y='Height_ft',hue='Year_introduced',data=df2)
# Out:
# <Axes: xlabel='Speed_mph', ylabel='Height_ft'>

# %%
df2.head()
# Out:
#                              Coaster_name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status   Opening date            Manufacturer Opened  Year_introduced  \
# 0  Removed  June 16, 1884  LaMarcus Adna Thompson    NaN             1884
# 1  Removed           1895            Lina Beecher    NaN             1895
# 2   Closed            NaN                     NaN   1895             1896
# 3  Removed           1901          Edwin Prescott    NaN             1901
# 4  Removed           1901          Edwin Prescott    NaN             1901
#
#    latitude  longitude Type_Main Opening_date  Speed_mph  Height_ft  \
# ...

# %%
sns.pairplot(df2, vars=['Year_introduced','Speed_mph','Height_ft','Inversions','GforceGforce_clean'],hue='Type_Main')

# %%
df2_corr=df2[['Year_introduced','Speed_mph','Height_ft','Inversions','GforceGforce_clean']].dropna().corr()

# %%
sns.heatmap(df2_corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # 5. Ask a Question about the data
#
# * Try to answer a question you have about the data using a plot or statistics

# %%
df2.head()
# Out:
#                              Coaster_name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status   Opening date            Manufacturer Opened  Year_introduced  \
# 0  Removed  June 16, 1884  LaMarcus Adna Thompson    NaN             1884
# 1  Removed           1895            Lina Beecher    NaN             1895
# 2   Closed            NaN                     NaN   1895             1896
# 3  Removed           1901          Edwin Prescott    NaN             1901
# 4  Removed           1901          Edwin Prescott    NaN             1901
#
#    latitude  longitude Type_Main Opening_date  Speed_mph  Height_ft  \
# ...

# %% [markdown]
# # What are location with the fastest rolloer #
#
# # coasters minimum of 10?

# %%
df2['Location'].value_counts()
# Out:
# Other                            181
# Kings Island                      19
# Cedar Point                       18
# Six Flags Magic Mountain          17
# Hersheypark                       16
#                                 ...
# Granada Studios Tour               1
# Funtown Splashtown USA             1
# Tolchester Beach Park              1
# Suzuka, Mie Prefecture, Japan      1
# Epcot                              1
# Name: Location, Length: 280, dtype: int64

# %%
ax = df2.query('Location != "Other"')\
.groupby("Location")['Speed_mph']\
.agg(['mean','count'])\
.query('count >= 10') \
.sort_values('mean')['mean']\
.plot(kind='barh',figsize = (12,5),title="Average Coast Speed by Location ")
ax.set_xlabel("Average Coaster Speed")
plt.show()

# %% [markdown]
# # That's all basic EDA
