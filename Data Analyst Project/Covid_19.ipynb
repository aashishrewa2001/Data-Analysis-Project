# %% [markdown]
# # **Covid_19 Dataset of 2020**

# %% [markdown]
# # Data Dictionary
#
# * **Date** ---> The date when the data was recorded
# * **State** ---> The name of the state or province where the data was recorded
# * **Region** -->  This column represent the name of the country or geographic region where the data was recorded
# * **Corfirmed** --> The number of confirmed cases of COVID-19 in the state or region as of the date recorded
# * **Deaths** ---> The number of deaths attributed to COVID-19 in the state or region as of the date recorded.
# * **Recovered** --->The number of people who have recovered from COVID-19 in the state or region as of the date recorded

# %%
import pandas as pd

# %%
 covid_19 = pd.read_csv("/content/drive/MyDrive/datasets/4. covid_19_data.csv")

# %%
covid_19
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data=covid_19

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Number of null values

# %%
sns.heatmap(data.isnull())
plt.title("Number of null values")
plt.show()

# %% [markdown]
# # 1. Show the number of Confirmed, and Recovered cases in each Region

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby("Region").sum()
# Out:
# <ipython-input-88-81ba19ab85cb>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby("Region").sum()
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region')["Confirmed","Recovered"].sum().head(20)
# Out:
# <ipython-input-90-ea658669a016>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')["Confirmed","Recovered"].sum().head(20)
#                      Confirmed  Recovered
# Region
# Afghanistan               1939        252
# Albania                    766        455
# Algeria                   3848       1702
# Andorra                    743        423
# Angola                      27          7
# Antigua and Barbuda         24         11
# Argentina                 4285       1192
# Armenia                   1932        900
# Australia                 6752       5715
# Austria                  15402      12779
# Azerbaijan                1766       1267
# Bahamas                     80         23
# Bahrain                   2921       1455
# Bangladesh                7103        150
# Barbados                    80         39
# Belarus                  13181       2072
# ...

# %% [markdown]
# # 2. Remove all the records where confirmed Cases is less than 10.

# %%
data.head(1)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252

# %%
data=data[(data.Confirmed >10)]

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [301 rows x 6 columns]

# %% [markdown]
# # In which Region , maximum number of Confirmed cases were recorded?

# %%
data.groupby('Region')["Confirmed"].sum().sort_values(ascending=False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166536
# UK                        166432
#                           ...
# Dominica                      16
# Saint Kitts and Nevis         15
# Nicaragua                     13
# Seychelles                    11
# Burundi                       11
# Name: Confirmed, Length: 177, dtype: int64

# %% [markdown]
# # 4. In which Region, minimum number of Deaths cases were recorded?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region')["Deaths"].sum().sort_values().head(50)
# Out:
# Region
# Fiji                                0
# Cambodia                            0
# Mozambique                          0
# Grenada                             0
# South Sudan                         0
# Dominica                            0
# Seychelles                          0
# Mongolia                            0
# Nepal                               0
# Namibia                             0
# Timor-Leste                         0
# Saint Vincent and the Grenadines    0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# Laos                                0
# Vietnam                             0
# Eritrea                             0
# Rwanda                              0
# Uganda                              0
# Macau                               0
# Madagascar                          0
# Liechtenstein                       1
# Eswatini                            1
# ...

# %% [markdown]
# # 5. How many confirmed,Deaths & Recovered cases were reported india till 29 April 2020?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[(data.Region == "India")]
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[(data.Region =="Years")]
# Out:
# Empty DataFrame
# Columns: [Date, State, Region, Confirmed, Deaths, Recovered]
# Index: []

# %%
data[data.Region =='US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %% [markdown]
# # 6.(A) Sor the entire data wrt No. of Confirmed cases in ascending order.

# %%
data.sort_values(by =['Confirmed'],ascending = True).head(50)
# Out:
#           Date                         State  \
# 27   4/29/2020                           NaN
# 318  4/29/2020                         Yukon
# 217  4/29/2020                     Greenland
# 144  4/29/2020                           NaN
# 256  4/29/2020                    Montserrat
# 306  4/29/2020      Turks and Caicos Islands
# 206  4/29/2020   Falkland Islands (Malvinas)
# 215  4/29/2020                Grand Princess
# 118  4/29/2020                           NaN
# 270  4/29/2020      Northern Mariana Islands
# 136  4/29/2020                           NaN
# 138  4/29/2020                           NaN
# 45   4/29/2020                           NaN
# 114  4/29/2020                           NaN
# 201  4/29/2020                       Curacao
# 137  4/29/2020                           NaN
# 281  4/29/2020                       Qinghai
# 55   4/29/2020                           NaN
# 260  4/29/2020                 New Caledonia
# 16   4/29/2020                           NaN
# ...

# %% [markdown]
# # 6. (B) Sort teh entire data wrt No. of Recovered cases in descending order

# %%
data.sort_values(by =['Recovered'],ascending = False).head(50)
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 78   4/29/2020              NaN               Ireland      20253    1190
# 8    4/29/2020              NaN               Austria      15402     580
# 107  4/29/2020              NaN                Mexico      17799    1732
# ...

# %% [markdown]
# # That's all EDA
